# %%
import numpy as np
import matplotlib.pyplot as plt

from sympy import *

# %% [markdown]
# # Plot Five Vector Fields

# %%
def vector_field(function, coordinate_range=[(-2,2),(-2,2)], resolution=20):
    """
    @author: Purusharth Saxena (@Jar-win)
    Vector Field function
       Input: 1. Function f(x,y) = P(x,y), Q(x,y) | [P(x,y), Q(x,y)]
              2. coordinate_range (type: <list>)
                                  [(-x,x),(-y,y)]
              3. Resolution: Number of points on which the function is evaluated.
    """
    a = np.linspace(coordinate_range[0][0], coordinate_range[0][1], resolution)
    b = np.linspace(coordinate_range[1][0], coordinate_range[1][1], resolution)
    X,Y = np.meshgrid(a,b) # creating meshgrid
    p = lambdify([x,y], function[0], "numpy")
    q = lambdify([x,y], function[1], "numpy")
    U = p(X,Y)
    V = q(X,Y)
    Q = plt.quiver(X, Y, U, V, units='width')
    plt.grid(True)
    plt.show()

if __name__ == '__main__':
    x,y = symbols('x y')
    func = [x**2,-y**2]#[x**y+x**2, y**y]
    v = vector_field(func, coordinate_range=[(-10,10),(-10,10)], resolution=25)

# %%
vector_field([sin(x)+cos(y), x**2])

# %%
vector_field([sin(x)+cos(y), tan(x+y)])

# %%
vector_field([sin(x)+cos(y), x**2+y**2])

# %%
vector_field([sin(x)+cos(y), cos(x)+sin(y)])

# %%
vector_field([sin(x), cos(y)])

# %%
import pylab as p
from numpy import *
from scipy import integrate

# %%
# Majority source: Scipycookbook
# Definition of parameters
a = 1.
b = 0.1
c = 1.5
d = 0.75

# %%
# Definition of parameters 
a = 1.
b = 0.1
c = 1.52
d = 0.75

f2 = p.figure()

# in plot trajectories
for v, col in zip(values, vcolors): 
    X0 = v * X_f1                               # starting point
    X = integrate.odeint( dX_dt, X0, t)         # we don't need infodict here
    p.plot( X[:,0], X[:,1], lw=3.5*v, color=col, label='X0=(%.f, %.f)' % ( X0[0], X0[1]) )

# Drow direction fields, using matplotlib 's quiver function
# color: growth speed
p.title('Trajectories and direction fields')
Q = p.quiver(X1, Y1, DX1, DY1, M, pivot='mid', cmap=p.cm.jet)
p.xlabel('Number of rabbits')
p.ylabel('Number of foxes')
p.legend()
p.grid()
p.xlim(0, xmax)
p.ylim(0, ymax)
f2.savefig('rabbits_and_foxes_2.png')
