# %%
import numpy as np

# %%
from collections import Counter

# %%
a = np.random.randint(255, size=(512, 512))

# %%
cnt = Counter()

# %%
512*512
# Out:
# 262144

# %%
abc = {}
counter = 0

# %%
for i in a:
    for j in i:
        if abc.get(str(j)):
            abc[str(j)] += 1
            counter +=1
        else:
            abc[str(j)] = 1

# %%
abc
# Out:
# {'8': 1041,
#  '163': 995,
#  '206': 1018,
#  '93': 1001,
#  '65': 1040,
#  '45': 1035,
#  '16': 1002,
#  '54': 1059,
#  '6': 1006,
#  '67': 1049,
#  '195': 1046,
#  '237': 1046,
#  '168': 1021,
#  '252': 1018,
#  '12': 1051,
#  '128': 1091,
#  '97': 1033,
#  '120': 1045,
#  '33': 1051,
#  '175': 998,
#  '152': 1047,
#  '178': 1006,
#  '9': 1025,
#  '197': 1006,
#  '22': 1042,
#  '171': 1037,
#  '30': 979,
#  '129': 1012,
#  '226': 1009,
#  '245': 1047,
#  '208': 997,
#  '42': 1028,
#  '192': 996,
#  '147': 996,
#  '180': 986,
#  '2': 954,
#  '183': 1041,
#  '207': 1000,
#  '90': 1013,
#  '32': 1032,
#  '236': 1092,
#  '107': 1012,
#  '174': 1033,
#  '11': 1046,
#  '114': 1080,
#  '241': 1031,
#  '74': 1029,
#  '235': 1031,
#  '79': 1022,
#  '38': 1010,
#  '28': 1059,
#  '73': 1077,
#  '142': 1015,
#  '26': 1019,
#  '0': 999,
#  '86': 981,
#  '124': 1002,
#  '24': 1002,
#  '191': 977,
#  '53': 995,
#  '238': 1009,
#  '179': 1044,
#  '10': 1015,
#  '150': 1064,
#  '62': 988,
# ...

# %%
counter
# Out:
# 261889
